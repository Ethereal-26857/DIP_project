# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 未安装相应包，安装后 报错解决

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
height, width = 256, 256   # 图像尺寸

# %% [markdown]
# 每一次重新进入之后需要重新导入一遍库，不然会报错

# %%
# 每一列的灰度值从0到255线性变化
smooth_image = np.tile(np.arange(width, dtype=np.uint8), (height, 1))

# %%
# 显示
plt.imshow(smooth_image, cmap='gray', vmin=0, vmax=255)
plt.title("Smooth Gray Image 0~255")
plt.axis('off')
plt.show()

# %%
# 每 16 像素灰度增加 16
band_width = 16
band_values = np.arange(0, 256, band_width, dtype=np.uint8)
mach_image = np.tile(band_values, (height, 1))

# %%
# 显示
plt.imshow(mach_image, cmap='gray', vmin=0, vmax=255)
plt.title("Mach Band Gray Image")
plt.axis('off')
plt.show()

# %%
# 每个 band 宽16像素，灰度值递增16
step_size = 16
bands = width // step_size
step_image = np.zeros((height, width), dtype=np.uint8)

for i in range(bands):
    step_image[:, i*step_size:(i+1)*step_size] = i * step_size

# %%
# 显示图像
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(smooth_image, cmap='gray', vmin=0, vmax=255)
axes[0].set_title('平滑灰阶渐变')
axes[0].axis('off')

axes[1].imshow(step_image, cmap='gray', vmin=0, vmax=255)
axes[1].set_title('阶梯灰阶图（观察 Mach band）')
axes[1].axis('off')

plt.show()
# Out:
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28369 (\N{CJK UNIFIED IDEOGRAPH-6ED1}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28784 (\N{CJK UNIFIED IDEOGRAPH-7070}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38454 (\N{CJK UNIFIED IDEOGRAPH-9636}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28176 (\N{CJK UNIFIED IDEOGRAPH-6E10}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26799 (\N{CJK UNIFIED IDEOGRAPH-68AF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 35266 (\N{CJK UNIFIED IDEOGRAPH-89C2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23519 (\N{CJK UNIFIED IDEOGRAPH-5BDF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\26971\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 字体缺失导致的报错

# %%
# 显示图像
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(smooth_image, cmap='gray', vmin=0, vmax=255)
axes[0].set_title('Smooth Gray Gradient')
axes[0].axis('off')

axes[1].imshow(step_image, cmap='gray', vmin=0, vmax=255)
axes[1].set_title('Step Gray Image (Observe Mach Band)')
axes[1].axis('off')

plt.show()

# %%
# 保存图像到文件
fig.savefig("gray_images.png", dpi=150)

# 打印一些信息
print("Smooth image shape:", smooth_image.shape)
print("Step image shape:", step_image.shape)
print("Step size per band:", step_size)
print("Number of bands:", bands)

# 突出 Mach band 效果，显示局部放大
fig2, ax2 = plt.subplots(1, 1, figsize=(6, 4))
# 放大第5个band的边界
zoom_band = step_image[:, 64:96]
ax2.imshow(zoom_band, cmap='gray', vmin=0, vmax=255)
ax2.set_title('Zoom on Step Band (Mach Band Effect)')
ax2.axis('off')
plt.show()
# Out:
# Smooth image shape: (256, 256)
# Step image shape: (256, 256)
# Step size per band: 16
# Number of bands: 16

# %%
import scipy.io as sio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import scipy.io as sio
#
# ModuleNotFoundError: No module named 'scipy'

# %%
import scipy.io as sio

# %%
# 读取 .mat 文件
mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"
mat_data = sio.loadmat(mat_path)

# 查看变量
print(mat_data.keys())  # dict_keys(['__header__', '__version__', '__globals__', 'data'])
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data'])

# %%
# 取出实际图像数组
image_struct = mat_data['data']

# 如果是嵌套数组（常见结构），取第一个元素
if isinstance(image_struct, np.ndarray) and image_struct.dtype == 'object':
    image = image_struct[0, 0]  # 提取真实图像
else:
    image = image_struct

print("Image shape:", image.shape)

# 定义灰度减少函数
def reduce_gray_levels(img, n):
    levels = 2 ** n
    img_normalized = img / 255.0                  # 归一化到0~1
    img_quantized = np.floor(img_normalized * levels) / levels  # 量化
    img_out = (img_quantized * 255).astype(np.uint8)           # 放大回0~255
    return img_out

# 生成不同灰度级图像
img_256 = reduce_gray_levels(image, 8)  # 256级灰度
img_64  = reduce_gray_levels(image, 6)  # 64级灰度
img_16  = reduce_gray_levels(image, 4)  # 16级灰度

# 显示图像
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(img_256, cmap='gray', vmin=0, vmax=255)
axes[0].set_title('256 Gray Levels')
axes[0].axis('off')

axes[1].imshow(img_64, cmap='gray', vmin=0, vmax=255)
axes[1].set_title('64 Gray Levels')
axes[1].axis('off')

axes[2].imshow(img_16, cmap='gray', vmin=0, vmax=255)
axes[2].set_title('16 Gray Levels')
axes[2].axis('off')

plt.show()
# Out:
# Image shape: (361, 361)

# %%
# 2. 定义灰度量化函数
def reduce_gray_levels(img, n):
    """
    将灰度图像量化为 2^n 个灰度级
    img: 输入图像 (np.ndarray)
    n: 灰度级参数，灰度级数为 2^n
    返回量化后的图像
    """
    levels = 2 ** n
    step = 256 // levels  # 每个灰度级的步长
    img_out = (img // step) * step
    return img_out.astype(np.uint8)

# 3. 生成不同灰度级的图像
img_256 = reduce_gray_levels(image, 8)   # 256级灰度
img_64  = reduce_gray_levels(image, 6)   # 64级灰度
img_16  = reduce_gray_levels(image, 4)   # 16级灰度

# 4. 显示图像
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].imshow(img_256, cmap='gray', vmin=0, vmax=255)
axes[0].set_title('256 Gray Levels')
axes[0].axis('off')

axes[1].imshow(img_64, cmap='gray', vmin=0, vmax=255)
axes[1].set_title('64 Gray Levels')
axes[1].axis('off')

axes[2].imshow(img_16, cmap='gray', vmin=0, vmax=255)
axes[2].set_title('16 Gray Levels')
axes[2].axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 参数设置
image_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"  # 原图路径
line_row = 100             # 取第100行作为比较线
N = 4                      # 缩小/放大的倍数

# 读取图像
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
if img is None:
    raise ValueError("图像路径不正确或文件不存在")

# 提取一行灰度值
original_line = img[line_row, :]

# 缩小图像
height, width = img.shape
small_img = cv2.resize(img, (width//N, height//N), interpolation=cv2.INTER_AREA)

# 放大回原大小
zoomed_img = cv2.resize(small_img, (width, height), interpolation=cv2.INTER_NEAREST)

# 提取缩放后图像的同一行灰度值
zoomed_line = zoomed_img[line_row, :]

# 可视化对比
plt.figure(figsize=(12, 6))

# 原图
plt.subplot(2, 2, 1)
plt.title("Original Image")
plt.imshow(img, cmap='gray')
plt.axhline(y=line_row, color='r', linestyle='--')  # 标出比较行

# 缩小后再放大图
plt.subplot(2, 2, 2)
plt.title(f"Reduced 1/{N} then Zoomed")
plt.imshow(zoomed_img, cmap='gray')
plt.axhline(y=line_row, color='r', linestyle='--')

# 灰度值对比
plt.subplot(2, 1, 2)
plt.title("Line Gray Values Comparison")
plt.plot(original_line, label="Original")
plt.plot(zoomed_line, label=f"Zoomed 1/{N}", linestyle='--')
plt.xlabel("Column Index")
plt.ylabel("Gray Value")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 13
#      11 img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
#      12 if img is None:
# ---> 13     raise ValueError("图像路径不正确或文件不存在")
#      15 # 提取一行灰度值
#      16 original_line = img[line_row, :]
#
# ValueError: 图像路径不正确或文件不存在

# %% [markdown]
# 电脑重启之后环境出现了一些问题，所以一直报错，现在已解决

# %%
import sys
print(sys.executable)
# Out:
# D:\coding\DIP_project\.venv\Scripts\python.exe

# %%
python -c "import cv2; print(cv2.__version__)"
# Out:
#   Cell In[5], line 1
#     python -c "import cv2; print(cv2.__version__)"
#               ^
# SyntaxError: invalid syntax

# %%
import os

image_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.png"
print(os.path.exists(image_path))
# Out:
# False

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import cv2  # 用于缩放操作

# 参数设置
mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"
line_row = 100  # 比较的行
N = 4           # 缩小/放大倍数

# 读取 .mat 文件
mat = sio.loadmat(mat_path)
# 假设灰度图保存在变量 'img' 中，如果名字不同请修改
if 'img' in mat:
    img = mat['img']
else:
    # 打印变量名，确认里面的图像变量
    print(mat.keys())
    raise ValueError("请确认 .mat 文件里图像变量名")

# 如果是二维图像，确保类型为 uint8
img = np.array(img, dtype=np.uint8)
height, width = img.shape

# 提取一行灰度值
# -----------------------
original_line = img[line_row, :]

# 缩小图像
small_img = cv2.resize(img, (width//N, height//N), interpolation=cv2.INTER_AREA)

# 放大回原大小
zoomed_img = cv2.resize(small_img, (width, height), interpolation=cv2.INTER_NEAREST)

# 提取缩放后图像的同一行灰度值
zoomed_line = zoomed_img[line_row, :]

# 可视化对比
plt.figure(figsize=(12, 6))

# 原图
plt.subplot(2, 2, 1)
plt.title("Original Image")
plt.imshow(img, cmap='gray')
plt.axhline(y=line_row, color='r', linestyle='--')  # 标出比较行

# 缩小后再放大图
plt.subplot(2, 2, 2)
plt.title(f"Reduced 1/{N} then Zoomed")
plt.imshow(zoomed_img, cmap='gray')
plt.axhline(y=line_row, color='r', linestyle='--')

# 灰度值对比
plt.subplot(2, 1, 2)
plt.title("Line Gray Values Comparison")
plt.plot(original_line, label="Original")
plt.plot(zoomed_line, label=f"Zoomed 1/{N}", linestyle='--')
plt.xlabel("Column Index")
plt.ylabel("Gray Value")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 19
#      16 else:
#      17     # 打印变量名，确认里面的图像变量
#      18     print(mat.keys())
# ---> 19     raise ValueError("请确认 .mat 文件里图像变量名")
#      21 # 如果是二维图像，确保类型为 uint8
#      22 img = np.array(img, dtype=np.uint8)
#
# ValueError: 请确认 .mat 文件里图像变量名

# %% [markdown]
# 图像变量名忘记设置了

# %%
import scipy.io as sio

mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"

mat = sio.loadmat(mat_path)
print(mat.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data'])

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import cv2  # 用于缩放操作

# 参数设置
mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"
line_row = 100  # 比较的行
N = 4           # 缩小/放大倍数

# 读取 .mat 文件
mat = sio.loadmat(mat_path)
if 'data' in mat:
    img = mat['data']
else:
    print(mat.keys())
    raise ValueError("请确认 .mat 文件里图像变量名")

# 确保是二维灰度图
img = np.array(img, dtype=np.uint8)
height, width = img.shape

# 提取一行灰度值
original_line = img[line_row, :]

# 缩小图像
small_img = cv2.resize(img, (width//N, height//N), interpolation=cv2.INTER_AREA)

# 放大回原大小
# -----------------------
zoomed_img = cv2.resize(small_img, (width, height), interpolation=cv2.INTER_NEAREST)

# 提取缩放后图像的同一行灰度值
zoomed_line = zoomed_img[line_row, :]

# 可视化对比
plt.figure(figsize=(12, 6))

# 原图
plt.subplot(2, 2, 1)
plt.title("Original Image")
plt.imshow(img, cmap='gray')
plt.axhline(y=line_row, color='r', linestyle='--')  # 标出比较行

# 缩小后再放大图
plt.subplot(2, 2, 2)
plt.title(f"Reduced 1/{N} then Zoomed")
plt.imshow(zoomed_img, cmap='gray')
plt.axhline(y=line_row, color='r', linestyle='--')

# 灰度值对比
plt.subplot(2, 1, 2)
plt.title("Line Gray Values Comparison")
plt.plot(original_line, label="Original")
plt.plot(zoomed_line, label=f"Zoomed 1/{N}", linestyle='--')
plt.xlabel("Column Index")
plt.ylabel("Gray Value")
plt.legend()

plt.tight_layout()
plt.show()

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# 参数设置
mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"
threshold = 128  # Color Overlay 阈值

# 读取 .mat 文件
mat = sio.loadmat(mat_path)
if 'data' in mat:
    img = mat['data']
else:
    print(mat.keys())
    raise ValueError("请确认 .mat 文件里图像变量名")

# 确保是二维灰度图
img = np.array(img, dtype=np.uint8)

# Color Overlay
# 生成 mask
mask = img > threshold  # 大于阈值的像素为 True

# 转成 3 通道彩色图
color_img = np.stack([img, img, img], axis=-1)

# mask 放入红色通道
color_img[mask, 0] = 255  # 红色通道
color_img[mask, 1] = img[mask]  # 保留绿色
color_img[mask, 2] = img[mask]  # 保留蓝色

# 可视化彩色叠加
plt.figure(figsize=(6, 6))
plt.imshow(color_img)
plt.title(f"Red Overlay: I > {threshold}")
plt.axis('off')
plt.show()

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# 参数设置
mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"
threshold = 128  # Color Overlay 阈值

# 读取 .mat 文件
mat = sio.loadmat(mat_path)
if 'data' in mat:
    img = mat['data']
else:
    print(mat.keys())
    raise ValueError("请确认 .mat 文件里图像变量名")

# 确保是二维灰度图
img = np.array(img, dtype=np.uint8)

# Color Overlay
# 生成 mask
mask = img > threshold  # 大于阈值的像素为 True

# 转成 3 通道彩色图
color_img = np.stack([img, img, img], axis=-1)

# mask 放入红色通道
color_img[mask, 0] = 255  # 红色通道
color_img[mask, 1] = 0  # 保留绿色
color_img[mask, 2] = 0  # 保留蓝色

# 可视化彩色叠加
plt.figure(figsize=(6, 6))
plt.imshow(color_img)
plt.title(f"Red Overlay: I > {threshold}")
plt.axis('off')
plt.show()

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# 参数设置
mat_path = r"D:\课程\专业课\生物医学图像处理\lab1\lab1.mat"
threshold = 222  # Color Overlay 阈值

# 读取 .mat 文件
mat = sio.loadmat(mat_path)
if 'data' in mat:
    img = mat['data']
else:
    print(mat.keys())
    raise ValueError("请确认 .mat 文件里图像变量名")

# 确保是二维灰度图
img = np.array(img, dtype=np.uint8)

# Color Overlay
# 生成 mask
mask = img > threshold  # 大于阈值的像素为 True

# 转成 3 通道彩色图
color_img = np.stack([img, img, img], axis=-1)

# mask 放入红色通道
color_img[mask, 0] = 255  # 红色通道
color_img[mask, 1] = 0  # 保留绿色
color_img[mask, 2] = 0  # 保留蓝色

# 可视化彩色叠加
plt.figure(figsize=(6, 6))
plt.imshow(color_img)
plt.title(f"Red Overlay: I > {threshold}")
plt.axis('off')
plt.show()
